# %% [markdown]
# <a href="https://colab.research.google.com/github/Cherinsoas/gittutorials/blob/main/files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = ["Cherinmon", "Santhumol", "Gee", "vivek", "krish", "lucas", "mahendra"]

for name in a:
    if "m" in name: # character to character comparison
        print(name)
# Out:
# Cherinmon
# Santhumol
# mahendra

# %%
a = "Monu"

# %%
a.lower()
# Out:
# 'monu'

# %%
a = "Kannan"

# %%
a = a.upper()

# %%
print(a)
# Out:
# KANNAN

# %%
a = "cherin"

# %%
a.title()
# Out:
# 'Cherin'

# %%
a = ["monu", "cherinmon", "Kannanmon", "vivek", "krish", "lucas", "Mahendra"]

for name in a:
    if "m" in name.lower() : # character to character comparison
        print(name)
# Out:
# monu
# cherinmon
# Kannanmon
# Mahendra

# %% [markdown]
# # code example

# %%
id = 1

# %%
name = input("enter your name : ")
age = input("enter age : ")

with open("test_dummy_1.txt", "a+") as f:
    a = str(id) + "," + name + "," + age +"," +"\n"
    f.write(a)
id += 1
# Out:
# enter your name : Gee
# enter age : 50

# %%
data_of_students = {}

# %%
def populate_data(data):
    print(data)
    data = data.split(",")
    print(data)
    data_of_students[str(data[0])] = {}
    data_of_students[str(data[0])][str("name")] = data[1]
    data_of_students[str(data[0])][str("age")] = data[2]

# %%
with open("./test_dummy_1.txt", "r+") as f:
    content = f.readlines()
    print(content)
    for c in content:
        populate_data(c)
# Out:
# ['1,Cherin,22,\n', '2,santhu,44,\n', '3,Gee,50,\n']
# 1,Cherin,22,
#
# ['1', 'Cherin', '22', '\n']
# 2,santhu,44,
#
# ['2', 'santhu', '44', '\n']
# 3,Gee,50,
#
# ['3', 'Gee', '50', '\n']

# %%
data_of_students
# Out:
# {'1': {'name': 'Cherin', 'age': '22'},
#  '2': {'name': 'santhu', 'age': '44'},
#  '3': {'name': 'Gee', 'age': '50'}}

# %%
a = {}

# %%
def add_to_dict(key, value):
    a[key] = value

# %%
add_to_dict("1", "Chein")
add_to_dict("2", "Santhu")
add_to_dict("3", "Aliamma")
add_to_dict("4", "=Geevarghese")

# %%
print(a)
# Out:
# {'1': 'Chein', '2': 'Santhu', '3': 'Aliamma', '4': '=Geevarghese'}
